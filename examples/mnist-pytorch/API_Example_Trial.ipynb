# %% [markdown]
# ## FEDn API Example
#
# This notebook provides an example of how to use the FEDn API to organize experiments and to analyze validation results. We will here run one training session using FedAvg and one session using FedAdam and compare the results.
#
# When you start this tutorial you should have a deployed FEDn Network up and running, and you should have created the compute package and the initial model, see the README for instructions.

# %%
import sys

venv_path = getattr(sys, 'base_prefix', sys.prefix)
print("Active virtual environment path:", venv_path)
# Out:
# Active virtual environment path: /Users/dininduseneviratne/opt/anaconda3

# %%
from fedn import APIClient
import time
import uuid
import json
import matplotlib.pyplot as plt
import numpy as np
import collections

# %% [markdown]
# We make a client connection to the FEDn API service. Here we assume that FEDn is deployed locally in pseudo-distributed mode with default ports.

# %%
DISCOVER_HOST = '127.0.0.1'
DISCOVER_PORT = 8092
client = APIClient(DISCOVER_HOST, DISCOVER_PORT)

# %% [markdown]
# Initialize FEDn with the compute package and seed model. Note that these files needs to be created separately by follwing instructions in the README.

# %%
client._get_url('set_package')
# Out:
# 'http://127.0.0.1:8092/set_package'

# %%
client.list_clients()
# Out:
# {'count': 4,
#  'result': [{'combiner': 'combiner',
#    'combiner_preferred': False,
#    'id': 'benign_client3',
#    'ip': '172.19.0.9',
#    'last_seen': 'Tue, 20 Feb 2024 11:06:45 GMT',
#    'status': 'online'},
#   {'combiner': 'combiner',
#    'combiner_preferred': False,
#    'id': 'benign_client2',
#    'ip': '172.19.0.8',
#    'last_seen': 'Tue, 20 Feb 2024 11:06:45 GMT',
#    'status': 'online'},
#   {'combiner': 'combiner',
#    'combiner_preferred': False,
#    'id': 'malignant_client1',
#    'ip': '172.19.0.10',
#    'last_seen': 'Tue, 20 Feb 2024 11:06:45 GMT',
#    'status': 'online'},
#   {'combiner': 'combiner',
#    'combiner_preferred': False,
#    'id': 'benign_client1',
#    'ip': '172.19.0.7',
#    'last_seen': 'Tue, 20 Feb 2024 11:06:45 GMT',
#    'status': 'online'}]}

# %%
# Show running client details
print("Running clients:")
for client in client.list_clients()['result']:
    if client['status'] == 'online':
        print(f"{client['ip']}: {client['id']}")
# Out:
# Running clients:
# 172.19.0.9: benign_client3
# 172.19.0.8: benign_client2
# 172.19.0.10: malignant_client1
# 172.19.0.7: benign_client1

# %%
client.set_package('package.tgz', 'numpyhelper')
client.set_initial_model('seed.npz')
seed_model = client.get_initial_model()

# %%
# seed_model
client.list_compute_packages()
# Out:
# {'count': 5,
#  'result': [{'committed_at': 'Tue, 20 Feb 2024 11:58:05 GMT',
#    'description': None,
#    'file_name': 'package.tgz',
#    'helper': 'numpyhelper',
#    'id': '373ba49b-6079-49e9-ac84-c82c7e2ec2dd',
#    'name': None,
#    'storage_file_name': 'f0e1e2c8-0a56-4438-8168-2b6c2feb3dcb.tgz'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:57:07 GMT',
#    'description': None,
#    'file_name': 'package.tgz',
#    'helper': 'numpyhelper',
#    'id': '5d2ccadb-cfa0-4967-bd1b-52503f0facb9',
#    'name': None,
#    'storage_file_name': '69446e0c-64bd-493f-b274-9eb3f059ebff.tgz'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:26:08 GMT',
#    'description': None,
#    'file_name': 'package.tgz',
#    'helper': 'numpyhelper',
#    'id': 'd6448a51-9e3a-49f3-87ca-6e5fe2da1154',
#    'name': None,
#    'storage_file_name': '5a23dd39-4e81-47f9-9462-2b8df1cffcf2.tgz'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:26:08 GMT',
#    'description': None,
#    'file_name': 'package.tgz',
#    'helper': 'numpyhelper',
#    'id': '854f0895-4390-4c35-862b-a3f190a4da9f',
#    'name': None,
#    'storage_file_name': '772c37cb-522d-46fc-923f-2993f29c8173.tgz'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:06:38 GMT',
#    'description': None,
#    'file_name': 'package.tgz',
#    'helper': 'numpyhelper',
#    'id': 'aa5b39e2-f185-44bc-b466-71f6cd3a8973',
#    'name': None,
#    'storage_file_name': 'cccb0b4c-be3b-47d0-acb1-7d7e72b1535a.tgz'}]}

# %% [markdown]
# Next we start a training session using FedAvg and wait until it has finished:

# %%
session_id = "experiment_fedavg_01"

session_config_fedavg = {
                    "helper": "numpyhelper",
                    "session_id": session_id,
                    "aggregator": "fedavg",
                    "model_id": seed_model['model_id'],
                    "rounds": 10
                 }

result_fedavg = client.start_session(**session_config_fedavg)

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_url',
#  'download_package',
#  'get_active_clients',
#  'get_client_config',
#  'get_combiner',
#  'get_controller_status',
#  'get_events',
#  'get_initial_model',
#  'get_latest_model',
#  'get_model_trail',
#  'get_package',
#  'get_package_checksum',
#  'get_round',
#  'get_session',
#  'host',
#  'list_clients',
#  'list_combiners',
#  'list_compute_packages',
#  'list_models',
#  'list_rounds',
#  'list_sessions',
#  'list_validations',
#  'port',
#  'secure',
#  'session_is_finished',
#  'set_initial_model',
#  'set_package',
#  'start_session',
#  'verify']

# %% [markdown]
# We wait for the session to finish:

# %%
client.session_is_finished('experiment_fedavg_01')
# Out:
# True

# %%
while not client.session_is_finished(session_id):
    time.sleep(2)

# %%
client.list_models(session_id)
# Out:
# {'count': 10,
#  'result': [{'committed_at': 'Tue, 20 Feb 2024 11:33:50 GMT',
#    'model': '485e7d67-e4fe-4197-b7d8-c7941ce9f15f',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:33:06 GMT',
#    'model': '6b8e87bb-4630-48e0-94a0-8d4013f48cf1',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:32:22 GMT',
#    'model': 'b9863a8f-91f6-41f8-85d5-9272abbdcbd9',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:31:34 GMT',
#    'model': '5f9c6ed1-8d50-4f58-82ec-d30b06e8346a',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:30:50 GMT',
#    'model': '67642a7b-3312-4538-b006-6a3057c654b9',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:30:05 GMT',
#    'model': 'fba286c8-b0ee-438b-b532-d06adfb1e03a',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:29:21 GMT',
#    'model': 'fda4b653-2be0-4da3-9829-3fb95a17038a',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:28:34 GMT',
#    'model': '86c0285c-098d-4899-9b0c-68ef73c37a26',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:27:50 GMT',
#    'model': '757ea7ae-c177-4247-8189-927f64f4a262',
#    'session_id': 'experiment_fedavg_01'},
#   {'committed_at': 'Tue, 20 Feb 2024 11:27:04 GMT',
#    'model': '65c4c90e-5619-4012-886e-5549016bce6c',
#    'session_id': 'experiment_fedavg_01'}]}

# %%
client.list_validations()
# Out:
# {'65d48c9b7613a25adef6d148': {'data': '{"training_loss": 1.4829061031341553, "training_accuracy": 0.7531999945640564, "test_loss": 1.392546534538269, "test_accuracy": 0.8059999942779541}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.533725Z'},
#  '65d48c9b7613a25adef6d149': {'data': '{"training_loss": 1.482998013496399, "training_accuracy": 0.7504000067710876, "test_loss": 1.570511817932129, "test_accuracy": 0.6919999718666077}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.534433Z'},
#  '65d48c9b7613a25adef6d14a': {'data': '{"training_loss": 1.5066980123519897, "training_accuracy": 0.7352666854858398, "test_loss": 1.4036338329315186, "test_accuracy": 0.7932000160217285}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.538777Z'},
#  '65d48c9b7613a25adef6d150': {'data': '{"training_loss": 1.4936631917953491, "training_accuracy": 0.7406666874885559, "test_loss": 1.552642822265625, "test_accuracy": 0.7031999826431274}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.622849Z'},
#  '65d48cc87613a25adef6d164': {'data': '{"training_loss": 0.51334148645401, "training_accuracy": 0.872866690158844, "test_loss": 0.6140707731246948, "test_accuracy": 0.8375999927520752}',
#   'meta': '',
#   'model_id': '757ea7ae-c177-4247-8189-927f64f4a262',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:08.407665Z'},
#  '65d48cc87613a25adef6d165': {'data': '{"training_loss": 0.4929639399051666, "training_accuracy": 0.880466639995575, "test_loss": 0.38188087940216064, "test_accuracy": 0.9196000099182129}',
#   'meta': '',
#   'model_id': '757ea7ae-c177-4247-8189-927f64f4a262',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:08.407245Z'},
#  '65d48cc87613a25adef6d16a': {'data': '{"training_loss": 0.5303382277488708, "training_accuracy": 0.8714666962623596, "test_loss": 0.3914545178413391, "test_accuracy": 0.9164000153541565}',
#   'meta': '',
#   'model_id': '757ea7ae-c177-4247-8189-927f64f4a262',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:08.496790Z'},
#  '65d48cc87613a25adef6d16b': {'data': '{"training_loss": 0.5146684050559998, "training_accuracy": 0.8727999925613403, "test_loss": 0.6020452380180359, "test_accuracy": 0.840399980545044}',
#   'meta': '',
#   'model_id': '757ea7ae-c177-4247-8189-927f64f4a262',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:08.497593Z'},
#  '65d48cf77613a25adef6d180': {'data': '{"training_loss": 0.3858078718185425, "training_accuracy": 0.8920000195503235, "test_loss": 0.2639773190021515, "test_accuracy": 0.9344000220298767}',
#   'meta': '',
#   'model_id': '86c0285c-098d-4899-9b0c-68ef73c37a26',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:54.998531Z'},
#  '65d48cf77613a25adef6d183': {'data': '{"training_loss": 0.3739112317562103, "training_accuracy": 0.8966000080108643, "test_loss": 0.45928075909614563, "test_accuracy": 0.864799976348877}',
#   'meta': '',
#   'model_id': '86c0285c-098d-4899-9b0c-68ef73c37a26',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:55.076512Z'},
#  '65d48cf77613a25adef6d186': {'data': '{"training_loss": 0.37181785702705383, "training_accuracy": 0.8952000141143799, "test_loss": 0.4472614824771881, "test_accuracy": 0.8655999898910522}',
#   'meta': '',
#   'model_id': '86c0285c-098d-4899-9b0c-68ef73c37a26',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:55.173523Z'},
#  '65d48cf77613a25adef6d189': {'data': '{"training_loss": 0.34824901819229126, "training_accuracy": 0.9037333130836487, "test_loss": 0.2579621970653534, "test_accuracy": 0.9336000084877014}',
#   'meta': '',
#   'model_id': '86c0285c-098d-4899-9b0c-68ef73c37a26',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:28:55.237185Z'},
#  '65d48d237613a25adef6d19c': {'data': '{"training_loss": 0.2959322929382324, "training_accuracy": 0.9137333035469055, "test_loss": 0.2168002426624298, "test_accuracy": 0.9408000111579895}',
#   'meta': '',
#   'model_id': 'fda4b653-2be0-4da3-9829-3fb95a17038a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:29:39.748156Z'},
#  '65d48d237613a25adef6d19d': {'data': '{"training_loss": 0.3236764669418335, "training_accuracy": 0.9054666757583618, "test_loss": 0.4003298282623291, "test_accuracy": 0.8772000074386597}',
#   'meta': '',
#   'model_id': 'fda4b653-2be0-4da3-9829-3fb95a17038a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:29:39.758105Z'},
#  '65d48d237613a25adef6d1a2': {'data': '{"training_loss": 0.33481496572494507, "training_accuracy": 0.9017333388328552, "test_loss": 0.22202742099761963, "test_accuracy": 0.9391999840736389}',
#   'meta': '',
#   'model_id': 'fda4b653-2be0-4da3-9829-3fb95a17038a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:29:39.810849Z'},
#  '65d48d237613a25adef6d1a3': {'data': '{"training_loss": 0.3197624087333679, "training_accuracy": 0.9057999849319458, "test_loss": 0.3885153532028198, "test_accuracy": 0.8795999884605408}',
#   'meta': '',
#   'model_id': 'fda4b653-2be0-4da3-9829-3fb95a17038a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:29:39.807830Z'},
#  '65d48d4f7613a25adef6d1b8': {'data': '{"training_loss": 0.28464165329933167, "training_accuracy": 0.9155333042144775, "test_loss": 0.3454420864582062, "test_accuracy": 0.896399974822998}',
#   'meta': '',
#   'model_id': 'fba286c8-b0ee-438b-b532-d06adfb1e03a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:30:23.618998Z'},
#  '65d48d4f7613a25adef6d1bb': {'data': '{"training_loss": 0.2854182720184326, "training_accuracy": 0.9139999747276306, "test_loss": 0.35785534977912903, "test_accuracy": 0.8916000127792358}',
#   'meta': '',
#   'model_id': 'fba286c8-b0ee-438b-b532-d06adfb1e03a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:30:23.653002Z'},
#  '65d48d4f7613a25adef6d1be': {'data': '{"training_loss": 0.29662880301475525, "training_accuracy": 0.9109333157539368, "test_loss": 0.19094538688659668, "test_accuracy": 0.9455999732017517}',
#   'meta': '',
#   'model_id': 'fba286c8-b0ee-438b-b532-d06adfb1e03a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:30:23.664351Z'},
#  '65d48d4f7613a25adef6d1c1': {'data': '{"training_loss": 0.25769323110580444, "training_accuracy": 0.9240000247955322, "test_loss": 0.1832120567560196, "test_accuracy": 0.9459999799728394}',
#   'meta': '',
#   'model_id': 'fba286c8-b0ee-438b-b532-d06adfb1e03a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:30:23.698129Z'},
#  '65d48d7c7613a25adef6d1d4': {'data': '{"training_loss": 0.2333044558763504, "training_accuracy": 0.9297333359718323, "test_loss": 0.16705738008022308, "test_accuracy": 0.9508000016212463}',
#   'meta': '',
#   'model_id': '67642a7b-3312-4538-b006-6a3057c654b9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:08.485500Z'},
#  '65d48d7c7613a25adef6d1d7': {'data': '{"training_loss": 0.26259753108024597, "training_accuracy": 0.9210666418075562, "test_loss": 0.3222596347332001, "test_accuracy": 0.9003999829292297}',
#   'meta': '',
#   'model_id': '67642a7b-3312-4538-b006-6a3057c654b9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:08.557473Z'},
#  '65d48d7c7613a25adef6d1da': {'data': '{"training_loss": 0.2628313899040222, "training_accuracy": 0.920199990272522, "test_loss": 0.3313531279563904, "test_accuracy": 0.8956000208854675}',
#   'meta': '',
#   'model_id': '67642a7b-3312-4538-b006-6a3057c654b9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:08.575841Z'},
#  '65d48d7c7613a25adef6d1db': {'data': '{"training_loss": 0.2751712501049042, "training_accuracy": 0.9179333448410034, "test_loss": 0.1707412600517273, "test_accuracy": 0.951200008392334}',
#   'meta': '',
#   'model_id': '67642a7b-3312-4538-b006-6a3057c654b9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:08.577376Z'},
#  '65d48da87613a25adef6d1f0': {'data': '{"training_loss": 0.24465367197990417, "training_accuracy": 0.9261333346366882, "test_loss": 0.307534396648407, "test_accuracy": 0.9035999774932861}',
#   'meta': '',
#   'model_id': '5f9c6ed1-8d50-4f58-82ec-d30b06e8346a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:52.402324Z'},
#  '65d48da87613a25adef6d1f1': {'data': '{"training_loss": 0.21509447693824768, "training_accuracy": 0.9354000091552734, "test_loss": 0.15223819017410278, "test_accuracy": 0.9524000287055969}',
#   'meta': '',
#   'model_id': '5f9c6ed1-8d50-4f58-82ec-d30b06e8346a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:52.429005Z'},
#  '65d48da87613a25adef6d1f6': {'data': '{"training_loss": 0.24480120837688446, "training_accuracy": 0.9265333414077759, "test_loss": 0.3006693124771118, "test_accuracy": 0.9088000059127808}',
#   'meta': '',
#   'model_id': '5f9c6ed1-8d50-4f58-82ec-d30b06e8346a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:52.494127Z'},
#  '65d48da87613a25adef6d1f8': {'data': '{"training_loss": 0.2565058171749115, "training_accuracy": 0.9226666688919067, "test_loss": 0.15612013638019562, "test_accuracy": 0.954800009727478}',
#   'meta': '',
#   'model_id': '5f9c6ed1-8d50-4f58-82ec-d30b06e8346a',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:31:52.507174Z'},
#  '65d48dd87613a25adef6d20c': {'data': '{"training_loss": 0.24395088851451874, "training_accuracy": 0.9258000254631042, "test_loss": 0.1477172076702118, "test_accuracy": 0.9580000042915344}',
#   'meta': '',
#   'model_id': 'b9863a8f-91f6-41f8-85d5-9272abbdcbd9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:32:40.734832Z'},
#  '65d48dd87613a25adef6d20f': {'data': '{"training_loss": 0.2001180350780487, "training_accuracy": 0.9400666952133179, "test_loss": 0.14558535814285278, "test_accuracy": 0.954800009727478}',
#   'meta': '',
#   'model_id': 'b9863a8f-91f6-41f8-85d5-9272abbdcbd9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:32:40.773842Z'},
#  '65d48dd87613a25adef6d211': {'data': '{"training_loss": 0.2321404069662094, "training_accuracy": 0.9300666451454163, "test_loss": 0.284074991941452, "test_accuracy": 0.9151999950408936}',
#   'meta': '',
#   'model_id': 'b9863a8f-91f6-41f8-85d5-9272abbdcbd9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:32:40.782006Z'},
#  '65d48dd87613a25adef6d215': {'data': '{"training_loss": 0.23086191713809967, "training_accuracy": 0.9292666912078857, "test_loss": 0.29445505142211914, "test_accuracy": 0.9052000045776367}',
#   'meta': '',
#   'model_id': 'b9863a8f-91f6-41f8-85d5-9272abbdcbd9',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:32:40.821159Z'},
#  '65d48e037613a25adef6d228': {'data': '{"training_loss": 0.22086457908153534, "training_accuracy": 0.9314666390419006, "test_loss": 0.28331559896469116, "test_accuracy": 0.909600019454956}',
#   'meta': '',
#   'model_id': '6b8e87bb-4630-48e0-94a0-8d4013f48cf1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:33:23.931051Z'},
#  '65d48e037613a25adef6d22b': {'data': '{"training_loss": 0.1891797035932541, "training_accuracy": 0.9434000253677368, "test_loss": 0.13983364403247833, "test_accuracy": 0.9563999772071838}',
#   'meta': '',
#   'model_id': '6b8e87bb-4630-48e0-94a0-8d4013f48cf1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:33:23.951001Z'},
#  '65d48e047613a25adef6d22e': {'data': '{"training_loss": 0.23259522020816803, "training_accuracy": 0.9283999800682068, "test_loss": 0.14037251472473145, "test_accuracy": 0.9575999975204468}',
#   'meta': '',
#   'model_id': '6b8e87bb-4630-48e0-94a0-8d4013f48cf1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:33:24.045172Z'},
#  '65d48e047613a25adef6d231': {'data': '{"training_loss": 0.2220005840063095, "training_accuracy": 0.9327333569526672, "test_loss": 0.27099794149398804, "test_accuracy": 0.9187999963760376}',
#   'meta': '',
#   'model_id': '6b8e87bb-4630-48e0-94a0-8d4013f48cf1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:33:24.094323Z'},
#  '65d48e2f7613a25adef6d240': {'data': '{"training_loss": 0.17834052443504333, "training_accuracy": 0.9467999935150146, "test_loss": 0.12966756522655487, "test_accuracy": 0.9599999785423279}',
#   'meta': '',
#   'model_id': '485e7d67-e4fe-4197-b7d8-c7941ce9f15f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:34:07.860292Z'},
#  '65d48e2f7613a25adef6d242': {'data': '{"training_loss": 0.21160730719566345, "training_accuracy": 0.9354000091552734, "test_loss": 0.2703952193260193, "test_accuracy": 0.9120000004768372}',
#   'meta': '',
#   'model_id': '485e7d67-e4fe-4197-b7d8-c7941ce9f15f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:34:07.880991Z'},
#  '65d48e2f7613a25adef6d244': {'data': '{"training_loss": 0.21263207495212555, "training_accuracy": 0.9356666803359985, "test_loss": 0.26152825355529785, "test_accuracy": 0.9200000166893005}',
#   'meta': '',
#   'model_id': '485e7d67-e4fe-4197-b7d8-c7941ce9f15f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:34:07.952864Z'},
#  '65d48e2f7613a25adef6d245': {'data': '{"training_loss": 0.2232816070318222, "training_accuracy": 0.9317333102226257, "test_loss": 0.13373108208179474, "test_accuracy": 0.9599999785423279}',
#   'meta': '',
#   'model_id': '485e7d67-e4fe-4197-b7d8-c7941ce9f15f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:34:07.956017Z'},
#  '65d495797613a25adef6d260': {'data': '{"training_loss": 1.4577161073684692, "training_accuracy": 0.7689333558082581, "test_loss": 1.3647187948226929, "test_accuracy": 0.8220000267028809}',
#   'meta': '',
#   'model_id': 'ec375dd4-56d0-4754-9852-5d66b6ad5815',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:13.001104Z'},
#  '65d495797613a25adef6d261': {'data': '{"training_loss": 1.4592540264129639, "training_accuracy": 0.7667333483695984, "test_loss": 1.5490179061889648, "test_accuracy": 0.7088000178337097}',
#   'meta': '',
#   'model_id': 'ec375dd4-56d0-4754-9852-5d66b6ad5815',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:13.002955Z'},
#  '65d495797613a25adef6d262': {'data': '{"training_loss": 1.483039379119873, "training_accuracy": 0.7544666528701782, "test_loss": 1.3757416009902954, "test_accuracy": 0.8116000294685364}',
#   'meta': '',
#   'model_id': 'ec375dd4-56d0-4754-9852-5d66b6ad5815',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:13.017251Z'},
#  '65d495797613a25adef6d263': {'data': '{"training_loss": 1.4702637195587158, "training_accuracy": 0.7568666934967041, "test_loss": 1.5329440832138062, "test_accuracy": 0.7179999947547913}',
#   'meta': '',
#   'model_id': 'ec375dd4-56d0-4754-9852-5d66b6ad5815',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:13.027713Z'},
#  '65d495a47613a25adef6d27c': {'data': '{"training_loss": 0.5270068645477295, "training_accuracy": 0.8704000115394592, "test_loss": 0.3895857632160187, "test_accuracy": 0.9124000072479248}',
#   'meta': '',
#   'model_id': 'b074ea5b-024a-4544-aa56-b40a97ac1bd1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:56.950903Z'},
#  '65d495a47613a25adef6d27d': {'data': '{"training_loss": 0.509795069694519, "training_accuracy": 0.8726000189781189, "test_loss": 0.6097500324249268, "test_accuracy": 0.8424000144004822}',
#   'meta': '',
#   'model_id': 'b074ea5b-024a-4544-aa56-b40a97ac1bd1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:56.953218Z'},
#  '65d495a47613a25adef6d27e': {'data': '{"training_loss": 0.4894436299800873, "training_accuracy": 0.8821333050727844, "test_loss": 0.3817663788795471, "test_accuracy": 0.9223999977111816}',
#   'meta': '',
#   'model_id': 'b074ea5b-024a-4544-aa56-b40a97ac1bd1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:56.987501Z'},
#  '65d495a57613a25adef6d285': {'data': '{"training_loss": 0.5125361680984497, "training_accuracy": 0.8723333477973938, "test_loss": 0.5966935753822327, "test_accuracy": 0.8428000211715698}',
#   'meta': '',
#   'model_id': 'b074ea5b-024a-4544-aa56-b40a97ac1bd1',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:05:57.047243Z'},
#  '65d495d07613a25adef6d298': {'data': '{"training_loss": 0.3853408396244049, "training_accuracy": 0.8911333084106445, "test_loss": 0.2640683650970459, "test_accuracy": 0.9291999936103821}',
#   'meta': '',
#   'model_id': 'cd9010db-7e87-4462-888b-fd558f1a06da',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:06:40.670938Z'},
#  '65d495d07613a25adef6d299': {'data': '{"training_loss": 0.36998477578163147, "training_accuracy": 0.8956000208854675, "test_loss": 0.44315868616104126, "test_accuracy": 0.8708000183105469}',
#   'meta': '',
#   'model_id': 'cd9010db-7e87-4462-888b-fd558f1a06da',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:06:40.674762Z'},
#  '65d495d07613a25adef6d29a': {'data': '{"training_loss": 0.34652528166770935, "training_accuracy": 0.9031999707221985, "test_loss": 0.2567296326160431, "test_accuracy": 0.9363999962806702}',
#   'meta': '',
#   'model_id': 'cd9010db-7e87-4462-888b-fd558f1a06da',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:06:40.685396Z'},
#  '65d495d07613a25adef6d29b': {'data': '{"training_loss": 0.37280145287513733, "training_accuracy": 0.8967333436012268, "test_loss": 0.4547070860862732, "test_accuracy": 0.8700000047683716}',
#   'meta': '',
#   'model_id': 'cd9010db-7e87-4462-888b-fd558f1a06da',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:06:40.697355Z'},
#  '65d495ff7613a25adef6d2b4': {'data': '{"training_loss": 0.3163478374481201, "training_accuracy": 0.9070666432380676, "test_loss": 0.382625013589859, "test_accuracy": 0.8827999830245972}',
#   'meta': '',
#   'model_id': 'a4052ed0-c202-4ba4-b3cd-08bc5ad1d5a2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:07:27.253647Z'},
#  '65d495ff7613a25adef6d2b5': {'data': '{"training_loss": 0.3184258043766022, "training_accuracy": 0.9079999923706055, "test_loss": 0.39530983567237854, "test_accuracy": 0.8831999897956848}',
#   'meta': '',
#   'model_id': 'a4052ed0-c202-4ba4-b3cd-08bc5ad1d5a2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:07:27.253567Z'},
#  '65d495ff7613a25adef6d2ba': {'data': '{"training_loss": 0.331410676240921, "training_accuracy": 0.9031999707221985, "test_loss": 0.21891677379608154, "test_accuracy": 0.9372000098228455}',
#   'meta': '',
#   'model_id': 'a4052ed0-c202-4ba4-b3cd-08bc5ad1d5a2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:07:27.363086Z'},
#  '65d495ff7613a25adef6d2bd': {'data': '{"training_loss": 0.2914154827594757, "training_accuracy": 0.9142000079154968, "test_loss": 0.21146249771118164, "test_accuracy": 0.942799985408783}',
#   'meta': '',
#   'model_id': 'a4052ed0-c202-4ba4-b3cd-08bc5ad1d5a2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:07:27.556705Z'},
#  '65d4962d7613a25adef6d2d0': {'data': '{"training_loss": 0.25856828689575195, "training_accuracy": 0.9243999719619751, "test_loss": 0.18251203000545502, "test_accuracy": 0.949999988079071}',
#   'meta': '',
#   'model_id': 'f0c74739-20f1-4889-b1c1-62570b16bb6b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:13.142105Z'},
#  '65d4962d7613a25adef6d2d3': {'data': '{"training_loss": 0.2989305555820465, "training_accuracy": 0.9110666513442993, "test_loss": 0.19086726009845734, "test_accuracy": 0.9435999989509583}',
#   'meta': '',
#   'model_id': 'f0c74739-20f1-4889-b1c1-62570b16bb6b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:13.174187Z'},
#  '65d4962d7613a25adef6d2d5': {'data': '{"training_loss": 0.28656524419784546, "training_accuracy": 0.9142666459083557, "test_loss": 0.3589840829372406, "test_accuracy": 0.8899999856948853}',
#   'meta': '',
#   'model_id': 'f0c74739-20f1-4889-b1c1-62570b16bb6b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:13.187203Z'},
#  '65d4962d7613a25adef6d2d9': {'data': '{"training_loss": 0.28572317957878113, "training_accuracy": 0.9154000282287598, "test_loss": 0.34276431798934937, "test_accuracy": 0.8912000060081482}',
#   'meta': '',
#   'model_id': 'f0c74739-20f1-4889-b1c1-62570b16bb6b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:13.213985Z'},
#  '65d496597613a25adef6d2ec': {'data': '{"training_loss": 0.2610737681388855, "training_accuracy": 0.9214666485786438, "test_loss": 0.3151088058948517, "test_accuracy": 0.8999999761581421}',
#   'meta': '',
#   'model_id': '3aa6d6a3-26a1-447f-8a5b-94268fe32b0f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:57.741831Z'},
#  '65d496597613a25adef6d2ee': {'data': '{"training_loss": 0.2749903202056885, "training_accuracy": 0.9172000288963318, "test_loss": 0.1717902421951294, "test_accuracy": 0.9472000002861023}',
#   'meta': '',
#   'model_id': '3aa6d6a3-26a1-447f-8a5b-94268fe32b0f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:57.755175Z'},
#  '65d496597613a25adef6d2ef': {'data': '{"training_loss": 0.23191481828689575, "training_accuracy": 0.9318000078201294, "test_loss": 0.1665354073047638, "test_accuracy": 0.9488000273704529}',
#   'meta': '',
#   'model_id': '3aa6d6a3-26a1-447f-8a5b-94268fe32b0f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:57.755491Z'},
#  '65d496597613a25adef6d2f5': {'data': '{"training_loss": 0.2609153091907501, "training_accuracy": 0.9219333529472351, "test_loss": 0.3292536735534668, "test_accuracy": 0.8999999761581421}',
#   'meta': '',
#   'model_id': '3aa6d6a3-26a1-447f-8a5b-94268fe32b0f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:08:57.872225Z'},
#  '65d496867613a25adef6d308': {'data': '{"training_loss": 0.21495366096496582, "training_accuracy": 0.9366666674613953, "test_loss": 0.1552881896495819, "test_accuracy": 0.9524000287055969}',
#   'meta': '',
#   'model_id': 'b831506e-dc11-4927-9435-d0814342651c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:09:42.865410Z'},
#  '65d496867613a25adef6d309': {'data': '{"training_loss": 0.24585959315299988, "training_accuracy": 0.9264000058174133, "test_loss": 0.29542094469070435, "test_accuracy": 0.9079999923706055}',
#   'meta': '',
#   'model_id': 'b831506e-dc11-4927-9435-d0814342651c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:09:42.885731Z'},
#  '65d496867613a25adef6d30a': {'data': '{"training_loss": 0.24480165541172028, "training_accuracy": 0.9263333082199097, "test_loss": 0.31076905131340027, "test_accuracy": 0.901199996471405}',
#   'meta': '',
#   'model_id': 'b831506e-dc11-4927-9435-d0814342651c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:09:42.867096Z'},
#  '65d496867613a25adef6d30b': {'data': '{"training_loss": 0.25883716344833374, "training_accuracy": 0.9218666553497314, "test_loss": 0.16002266108989716, "test_accuracy": 0.954800009727478}',
#   'meta': '',
#   'model_id': 'b831506e-dc11-4927-9435-d0814342651c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:09:42.868403Z'},
#  '65d496b37613a25adef6d324': {'data': '{"training_loss": 0.24352648854255676, "training_accuracy": 0.9267333149909973, "test_loss": 0.1458912044763565, "test_accuracy": 0.9592000246047974}',
#   'meta': '',
#   'model_id': '7b4b8d0c-8940-4fdc-ab73-665509cb03df',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:10:27.684954Z'},
#  '65d496b37613a25adef6d327': {'data': '{"training_loss": 0.19665312767028809, "training_accuracy": 0.9422666430473328, "test_loss": 0.14414606988430023, "test_accuracy": 0.9535999894142151}',
#   'meta': '',
#   'model_id': '7b4b8d0c-8940-4fdc-ab73-665509cb03df',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:10:27.749719Z'},
#  '65d496b37613a25adef6d32a': {'data': '{"training_loss": 0.22796757519245148, "training_accuracy": 0.9312666654586792, "test_loss": 0.29304400086402893, "test_accuracy": 0.909600019454956}',
#   'meta': '',
#   'model_id': '7b4b8d0c-8940-4fdc-ab73-665509cb03df',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:10:27.810098Z'},
#  '65d496b37613a25adef6d32c': {'data': '{"training_loss": 0.23091121017932892, "training_accuracy": 0.9309999942779541, "test_loss": 0.27844852209091187, "test_accuracy": 0.9139999747276306}',
#   'meta': '',
#   'model_id': '7b4b8d0c-8940-4fdc-ab73-665509cb03df',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:10:27.814631Z'},
#  '65d496df7613a25adef6d340': {'data': '{"training_loss": 0.2326982170343399, "training_accuracy": 0.9300666451454163, "test_loss": 0.13957367837429047, "test_accuracy": 0.9603999853134155}',
#   'meta': '',
#   'model_id': 'e1797a0b-819e-425c-8449-89f4dc12eff2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:11.706540Z'},
#  '65d496df7613a25adef6d341': {'data': '{"training_loss": 0.21855202317237854, "training_accuracy": 0.9330000281333923, "test_loss": 0.2809317111968994, "test_accuracy": 0.9128000140190125}',
#   'meta': '',
#   'model_id': 'e1797a0b-819e-425c-8449-89f4dc12eff2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:11.712309Z'},
#  '65d496df7613a25adef6d346': {'data': '{"training_loss": 0.22081904113292694, "training_accuracy": 0.9341999888420105, "test_loss": 0.2652672231197357, "test_accuracy": 0.9164000153541565}',
#   'meta': '',
#   'model_id': 'e1797a0b-819e-425c-8449-89f4dc12eff2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:11.726124Z'},
#  '65d496df7613a25adef6d349': {'data': '{"training_loss": 0.18581683933734894, "training_accuracy": 0.9455999732017517, "test_loss": 0.13606923818588257, "test_accuracy": 0.9567999839782715}',
#   'meta': '',
#   'model_id': 'e1797a0b-819e-425c-8449-89f4dc12eff2',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:11.757759Z'},
#  '65d4970b7613a25adef6d358': {'data': '{"training_loss": 0.1725183129310608, "training_accuracy": 0.9490000009536743, "test_loss": 0.12941360473632812, "test_accuracy": 0.9607999920845032}',
#   'meta': '',
#   'model_id': '3c0dcc97-4144-4009-b3c7-884294fb257c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:55.878128Z'},
#  '65d4970b7613a25adef6d359': {'data': '{"training_loss": 0.22189562022686005, "training_accuracy": 0.9333333373069763, "test_loss": 0.13003754615783691, "test_accuracy": 0.9635999798774719}',
#   'meta': '',
#   'model_id': '3c0dcc97-4144-4009-b3c7-884294fb257c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:55.878325Z'},
#  '65d4970b7613a25adef6d35a': {'data': '{"training_loss": 0.20813289284706116, "training_accuracy": 0.9367333054542542, "test_loss": 0.2655697166919708, "test_accuracy": 0.9192000031471252}',
#   'meta': '',
#   'model_id': '3c0dcc97-4144-4009-b3c7-884294fb257c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:55.895678Z'},
#  '65d4970b7613a25adef6d35e': {'data': '{"training_loss": 0.20913945138454437, "training_accuracy": 0.9376000165939331, "test_loss": 0.2545958161354065, "test_accuracy": 0.91839998960495}',
#   'meta': '',
#   'model_id': '3c0dcc97-4144-4009-b3c7-884294fb257c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T12:11:55.927598Z'},
#  '65d4b4867613a25adef6d378': {'data': '{"training_loss": 1.4947434663772583, "training_accuracy": 0.7483999729156494, "test_loss": 1.3897442817687988, "test_accuracy": 0.8047999739646912}',
#   'meta': '',
#   'model_id': '9d171e6b-f049-4cae-9b90-edd3bdfc4ef8',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:17:42.801438Z'},
#  '65d4b4867613a25adef6d37b': {'data': '{"training_loss": 1.470750331878662, "training_accuracy": 0.760200023651123, "test_loss": 1.5628200769424438, "test_accuracy": 0.6967999935150146}',
#   'meta': '',
#   'model_id': '9d171e6b-f049-4cae-9b90-edd3bdfc4ef8',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:17:42.957071Z'},
#  '65d4b4877613a25adef6d37e': {'data': '{"training_loss": 1.4708423614501953, "training_accuracy": 0.7621999979019165, "test_loss": 1.3767558336257935, "test_accuracy": 0.8216000199317932}',
#   'meta': '',
#   'model_id': '9d171e6b-f049-4cae-9b90-edd3bdfc4ef8',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:17:43.018645Z'},
#  '65d4b4877613a25adef6d381': {'data': '{"training_loss": 1.482276201248169, "training_accuracy": 0.7491999864578247, "test_loss": 1.546364665031433, "test_accuracy": 0.7063999772071838}',
#   'meta': '',
#   'model_id': '9d171e6b-f049-4cae-9b90-edd3bdfc4ef8',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:17:43.085745Z'},
#  '65d4b4b77613a25adef6d394': {'data': '{"training_loss": 0.49081656336784363, "training_accuracy": 0.8843333125114441, "test_loss": 0.3875839412212372, "test_accuracy": 0.920799970626831}',
#   'meta': '',
#   'model_id': '374e41bf-0433-43a7-a6c4-0444ec5cbb8b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:18:31.432152Z'},
#  '65d4b4b77613a25adef6d395': {'data': '{"training_loss": 0.5279492735862732, "training_accuracy": 0.871066689491272, "test_loss": 0.39313575625419617, "test_accuracy": 0.9115999937057495}',
#   'meta': '',
#   'model_id': '374e41bf-0433-43a7-a6c4-0444ec5cbb8b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:18:31.432997Z'},
#  '65d4b4b77613a25adef6d39a': {'data': '{"training_loss": 0.5109099745750427, "training_accuracy": 0.8759333491325378, "test_loss": 0.609900951385498, "test_accuracy": 0.8443999886512756}',
#   'meta': '',
#   'model_id': '374e41bf-0433-43a7-a6c4-0444ec5cbb8b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:18:31.471295Z'},
#  '65d4b4b77613a25adef6d39d': {'data': '{"training_loss": 0.5130712389945984, "training_accuracy": 0.8752666711807251, "test_loss": 0.5980933308601379, "test_accuracy": 0.8407999873161316}',
#   'meta': '',
#   'model_id': '374e41bf-0433-43a7-a6c4-0444ec5cbb8b',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:18:31.485107Z'},
#  '65d4b4e57613a25adef6d3b0': {'data': '{"training_loss": 0.3885667026042938, "training_accuracy": 0.8885999917984009, "test_loss": 0.26726168394088745, "test_accuracy": 0.9279999732971191}',
#   'meta': '',
#   'model_id': '6b7d0920-6e37-43d4-81c8-034b08658a99',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:19:17.876045Z'},
#  '65d4b4e67613a25adef6d3b3': {'data': '{"training_loss": 0.37546977400779724, "training_accuracy": 0.8952000141143799, "test_loss": 0.46065494418144226, "test_accuracy": 0.8659999966621399}',
#   'meta': '',
#   'model_id': '6b7d0920-6e37-43d4-81c8-034b08658a99',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:19:18.004803Z'},
#  '65d4b4e67613a25adef6d3b4': {'data': '{"training_loss": 0.35119014978408813, "training_accuracy": 0.9014000296592712, "test_loss": 0.25899091362953186, "test_accuracy": 0.9323999881744385}',
#   'meta': '',
#   'model_id': '6b7d0920-6e37-43d4-81c8-034b08658a99',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:19:18.009264Z'},
#  '65d4b4e67613a25adef6d3b5': {'data': '{"training_loss": 0.3751622140407562, "training_accuracy": 0.8937333226203918, "test_loss": 0.45072901248931885, "test_accuracy": 0.8651999831199646}',
#   'meta': '',
#   'model_id': '6b7d0920-6e37-43d4-81c8-034b08658a99',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:19:18.009532Z'},
#  '65d4b5137613a25adef6d3cc': {'data': '{"training_loss": 0.2888484001159668, "training_accuracy": 0.9139999747276306, "test_loss": 0.2119365930557251, "test_accuracy": 0.9395999908447266}',
#   'meta': '',
#   'model_id': 'e46c1e6a-0ba0-4700-adb0-ef44252cce5f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:03.815408Z'},
#  '65d4b5137613a25adef6d3cf': {'data': '{"training_loss": 0.316425085067749, "training_accuracy": 0.9071333408355713, "test_loss": 0.3937160074710846, "test_accuracy": 0.8772000074386597}',
#   'meta': '',
#   'model_id': 'e46c1e6a-0ba0-4700-adb0-ef44252cce5f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:03.906832Z'},
#  '65d4b5137613a25adef6d3d0': {'data': '{"training_loss": 0.327987402677536, "training_accuracy": 0.9017999768257141, "test_loss": 0.21623043715953827, "test_accuracy": 0.9372000098228455}',
#   'meta': '',
#   'model_id': 'e46c1e6a-0ba0-4700-adb0-ef44252cce5f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:03.915217Z'},
#  '65d4b5137613a25adef6d3d2': {'data': '{"training_loss": 0.3149590790271759, "training_accuracy": 0.9065333604812622, "test_loss": 0.38207364082336426, "test_accuracy": 0.8844000101089478}',
#   'meta': '',
#   'model_id': 'e46c1e6a-0ba0-4700-adb0-ef44252cce5f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:03.926059Z'},
#  '65d4b5427613a25adef6d3e8': {'data': '{"training_loss": 0.282124400138855, "training_accuracy": 0.9163333177566528, "test_loss": 0.3460775911808014, "test_accuracy": 0.892799973487854}',
#   'meta': '',
#   'model_id': 'e8f3d1c1-9e8e-4dbd-a0d2-d88743e909ad',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:50.167037Z'},
#  '65d4b5427613a25adef6d3eb': {'data': '{"training_loss": 0.2548833191394806, "training_accuracy": 0.9241333603858948, "test_loss": 0.18658797442913055, "test_accuracy": 0.9472000002861023}',
#   'meta': '',
#   'model_id': 'e8f3d1c1-9e8e-4dbd-a0d2-d88743e909ad',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:50.211206Z'},
#  '65d4b5427613a25adef6d3ee': {'data': '{"training_loss": 0.2956209182739258, "training_accuracy": 0.9118000268936157, "test_loss": 0.19023650884628296, "test_accuracy": 0.9440000057220459}',
#   'meta': '',
#   'model_id': 'e8f3d1c1-9e8e-4dbd-a0d2-d88743e909ad',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:50.239662Z'},
#  '65d4b5427613a25adef6d3ef': {'data': '{"training_loss": 0.2844716012477875, "training_accuracy": 0.9156666398048401, "test_loss": 0.35336214303970337, "test_accuracy": 0.8863999843597412}',
#   'meta': '',
#   'model_id': 'e8f3d1c1-9e8e-4dbd-a0d2-d88743e909ad',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:20:50.246698Z'},
#  '65d4b56e7613a25adef6d404': {'data': '{"training_loss": 0.26282164454460144, "training_accuracy": 0.9222666621208191, "test_loss": 0.321530818939209, "test_accuracy": 0.9035999774932861}',
#   'meta': '',
#   'model_id': '7a0dc536-d9af-44b8-b6fb-cb07dfa67b4e',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:21:34.497383Z'},
#  '65d4b56e7613a25adef6d406': {'data': '{"training_loss": 0.26186689734458923, "training_accuracy": 0.9211333394050598, "test_loss": 0.33282411098480225, "test_accuracy": 0.8960000276565552}',
#   'meta': '',
#   'model_id': '7a0dc536-d9af-44b8-b6fb-cb07dfa67b4e',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:21:34.527866Z'},
#  '65d4b56e7613a25adef6d408': {'data': '{"training_loss": 0.2742959260940552, "training_accuracy": 0.9171333312988281, "test_loss": 0.17088092863559723, "test_accuracy": 0.951200008392334}',
#   'meta': '',
#   'model_id': '7a0dc536-d9af-44b8-b6fb-cb07dfa67b4e',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:21:34.532160Z'},
#  '65d4b56e7613a25adef6d40d': {'data': '{"training_loss": 0.23273690044879913, "training_accuracy": 0.9300666451454163, "test_loss": 0.16972807049751282, "test_accuracy": 0.9527999758720398}',
#   'meta': '',
#   'model_id': '7a0dc536-d9af-44b8-b6fb-cb07dfa67b4e',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:21:34.622279Z'},
#  '65d4b59a7613a25adef6d420': {'data': '{"training_loss": 0.24318888783454895, "training_accuracy": 0.9272000193595886, "test_loss": 0.30808717012405396, "test_accuracy": 0.9043999910354614}',
#   'meta': '',
#   'model_id': '4c08a0c6-bf1b-43ea-ad04-21da8a1b555c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:22:18.106828Z'},
#  '65d4b59a7613a25adef6d421': {'data': '{"training_loss": 0.2442367821931839, "training_accuracy": 0.9278666377067566, "test_loss": 0.30117809772491455, "test_accuracy": 0.9071999788284302}',
#   'meta': '',
#   'model_id': '4c08a0c6-bf1b-43ea-ad04-21da8a1b555c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:22:18.107539Z'},
#  '65d4b59a7613a25adef6d422': {'data': '{"training_loss": 0.25465723872184753, "training_accuracy": 0.9225333333015442, "test_loss": 0.15755197405815125, "test_accuracy": 0.9552000164985657}',
#   'meta': '',
#   'model_id': '4c08a0c6-bf1b-43ea-ad04-21da8a1b555c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:22:18.118513Z'},
#  '65d4b59a7613a25adef6d426': {'data': '{"training_loss": 0.21210509538650513, "training_accuracy": 0.9372000098228455, "test_loss": 0.15644031763076782, "test_accuracy": 0.9535999894142151}',
#   'meta': '',
#   'model_id': '4c08a0c6-bf1b-43ea-ad04-21da8a1b555c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:22:18.144983Z'},
#  '65d4b5c67613a25adef6d43c': {'data': '{"training_loss": 0.19969864189624786, "training_accuracy": 0.9395999908447266, "test_loss": 0.1487061083316803, "test_accuracy": 0.9559999704360962}',
#   'meta': '',
#   'model_id': 'ba265583-b575-425d-9a24-75d9ba79a28d',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:02.013036Z'},
#  '65d4b5c67613a25adef6d43f': {'data': '{"training_loss": 0.23230664432048798, "training_accuracy": 0.9294666647911072, "test_loss": 0.2982463538646698, "test_accuracy": 0.9100000262260437}',
#   'meta': '',
#   'model_id': 'ba265583-b575-425d-9a24-75d9ba79a28d',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:02.128046Z'},
#  '65d4b5c67613a25adef6d442': {'data': '{"training_loss": 0.23299343883991241, "training_accuracy": 0.9302666783332825, "test_loss": 0.2896985113620758, "test_accuracy": 0.9107999801635742}',
#   'meta': '',
#   'model_id': 'ba265583-b575-425d-9a24-75d9ba79a28d',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:02.177442Z'},
#  '65d4b5c67613a25adef6d445': {'data': '{"training_loss": 0.2428349107503891, "training_accuracy": 0.9258000254631042, "test_loss": 0.14837679266929626, "test_accuracy": 0.9575999975204468}',
#   'meta': '',
#   'model_id': 'ba265583-b575-425d-9a24-75d9ba79a28d',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:02.209009Z'},
#  '65d4b5f27613a25adef6d458': {'data': '{"training_loss": 0.23033146560192108, "training_accuracy": 0.9291999936103821, "test_loss": 0.1405860334634781, "test_accuracy": 0.9616000056266785}',
#   'meta': '',
#   'model_id': '107824ca-18cd-4d24-bae2-5f108490e1bc',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:46.935650Z'},
#  '65d4b5f27613a25adef6d459': {'data': '{"training_loss": 0.2195197492837906, "training_accuracy": 0.9319999814033508, "test_loss": 0.2837167978286743, "test_accuracy": 0.9088000059127808}',
#   'meta': '',
#   'model_id': '107824ca-18cd-4d24-bae2-5f108490e1bc',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:46.941464Z'},
#  '65d4b5f27613a25adef6d45a': {'data': '{"training_loss": 0.18603919446468353, "training_accuracy": 0.9431333541870117, "test_loss": 0.141845241189003, "test_accuracy": 0.9567999839782715}',
#   'meta': '',
#   'model_id': '107824ca-18cd-4d24-bae2-5f108490e1bc',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:46.943745Z'},
#  '65d4b5f27613a25adef6d45b': {'data': '{"training_loss": 0.22079548239707947, "training_accuracy": 0.9336000084877014, "test_loss": 0.273860901594162, "test_accuracy": 0.9143999814987183}',
#   'meta': '',
#   'model_id': '107824ca-18cd-4d24-bae2-5f108490e1bc',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:23:46.961654Z'},
#  '65d4b61f7613a25adef6d470': {'data': '{"training_loss": 0.20955286920070648, "training_accuracy": 0.9356666803359985, "test_loss": 0.2690904140472412, "test_accuracy": 0.9168000221252441}',
#   'meta': '',
#   'model_id': '05a26600-7f78-4129-932c-356ef2f958b3',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:24:31.142310Z'},
#  '65d4b61f7613a25adef6d472': {'data': '{"training_loss": 0.22053872048854828, "training_accuracy": 0.9323999881744385, "test_loss": 0.13479399681091309, "test_accuracy": 0.9624000191688538}',
#   'meta': '',
#   'model_id': '05a26600-7f78-4129-932c-356ef2f958b3',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:24:31.206658Z'},
#  '65d4b61f7613a25adef6d474': {'data': '{"training_loss": 0.21188601851463318, "training_accuracy": 0.9363999962806702, "test_loss": 0.26170602440834045, "test_accuracy": 0.9215999841690063}',
#   'meta': '',
#   'model_id': '05a26600-7f78-4129-932c-356ef2f958b3',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:24:31.231039Z'},
#  '65d4b61f7613a25adef6d475': {'data': '{"training_loss": 0.1756618320941925, "training_accuracy": 0.9475333094596863, "test_loss": 0.13199995458126068, "test_accuracy": 0.9595999717712402}',
#   'meta': '',
#   'model_id': '05a26600-7f78-4129-932c-356ef2f958b3',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T14:24:31.237285Z'}}

# %% [markdown]
# Next, we retrive all model validations from all clients, extract the training accuracy metric, and compute its mean value accross all clients

# %%
models = client.list_models(session_id)

validations = []
acc = collections.OrderedDict()
for model in models["result"]:
    model_id = model["model"]
    validations = client.list_validations(modelId=model_id)

    for _ , validation in validations.items(): 
        metrics = json.loads(validation['data'])
        try:
            acc[model_id].append(metrics['training_accuracy'])
        except KeyError: 
            acc[model_id] = [metrics['training_accuracy']]
            
mean_acc_fedavg = []
for model, data in acc.items():
    mean_acc_fedavg.append(np.mean(data))
mean_acc_fedavg.reverse()

# %%
validations
# Out:
# {'65d48c9b7613a25adef6d148': {'data': '{"training_loss": 1.4829061031341553, "training_accuracy": 0.7531999945640564, "test_loss": 1.392546534538269, "test_accuracy": 0.8059999942779541}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malignant_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.533725Z'},
#  '65d48c9b7613a25adef6d149': {'data': '{"training_loss": 1.482998013496399, "training_accuracy": 0.7504000067710876, "test_loss": 1.570511817932129, "test_accuracy": 0.6919999718666077}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.534433Z'},
#  '65d48c9b7613a25adef6d14a': {'data': '{"training_loss": 1.5066980123519897, "training_accuracy": 0.7352666854858398, "test_loss": 1.4036338329315186, "test_accuracy": 0.7932000160217285}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.538777Z'},
#  '65d48c9b7613a25adef6d150': {'data': '{"training_loss": 1.4936631917953491, "training_accuracy": 0.7406666874885559, "test_loss": 1.552642822265625, "test_accuracy": 0.7031999826431274}',
#   'meta': '',
#   'model_id': '65c4c90e-5619-4012-886e-5549016bce6c',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-02-20T11:27:23.622849Z'}}

# %%
x = range(1,len(mean_acc_fedavg)+1)
plt.plot(x, mean_acc_fedavg)
plt.legend(['Training Accuracy (FedAvg)'])

# %% [markdown]
# Let's try another aggregation algorithm. We start another session using FedOpt (FedAdam)

# %%
session_config_fedopt = {
                    "helper": "numpyhelper",
                    "session_id": "experiment_fedopt_01",
                    "aggregator": "fedopt",
                    "model_id": seed_model['model_id'],
                    "rounds": 10
                 }

result_fedopt = client.start_session(**session_config_fedopt)

# %%
while not client.session_is_finished("experiment_fedopt"):
    time.sleep(2)

# %%
client.session_is_finished("experiment_fedopt_01")
# Out:
# True

# %%
models = client.list_models(session_id = "experiment_fedopt_01")

validations = []
acc = collections.OrderedDict()
for model in models["result"]:
    model_id = model["model"]
    validations = client.list_validations(modelId=model_id)
    for _ , validation in validations.items(): 
        metrics = json.loads(validation['data'])
        try:
            acc[model_id].append(metrics['training_accuracy'])
        except KeyError: 
            acc[model_id] = [metrics['training_accuracy']]
            
mean_acc_fedopt = []
for model, data in acc.items():
    mean_acc_fedopt.append(np.mean(data))
mean_acc_fedopt.reverse()

# %% [markdown]
# Finally, plot the resulting accuracy

# %%
x = range(1,len(mean_acc_fedavg)+1)
plt.plot(x, mean_acc_fedavg_clean, x, mean_acc_fedavg, x, mean_acc_fedopt)
plt.legend(['FedAvg-Clean', 'FedAvg', 'FedAdam'])
plt.show()
